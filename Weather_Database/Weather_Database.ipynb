# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
# YOUR CODE HERE
len(cities)
# Out:
# 733

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description" : city_description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kruisfontein
# Processing Record 2 of Set 1 | padang
# Processing Record 3 of Set 1 | goderich
# Processing Record 4 of Set 1 | alyangula
# Processing Record 5 of Set 1 | ouro preto do oeste
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | launceston
# Processing Record 9 of Set 1 | saint george
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | tasiilaq
# Processing Record 12 of Set 1 | wajima
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | road town
# Processing Record 16 of Set 1 | pasni
# Processing Record 17 of Set 1 | tevriz
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | gazojak
# Processing Record 21 of Set 1 | hambantota
# Processing Record 22 of Set 1 | hami
# Processing Record 23 of Set 1 | banyo
# Processing Record 24 of Set 1 | portland
# Processing Record 25 of Set 1 | cabo san lucas
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | clarence town
# Processing Record 28 of Set 1 | los llanos de aridane
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | nsunga
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | lavrentiya
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | olinda
# Processing Record 35 of Set 1 | ostrovnoy
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | brae
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | kyra
# Processing Record 40 of Set 1 | kologriv
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | binga
# Processing Record 43 of Set 1 | longyearbyen
# Processing Record 44 of Set 1 | san-pedro
# Processing Record 45 of Set 1 | kulhudhuffushi
# Processing Record 46 of Set 1 | adrar
# Processing Record 47 of Set 1 | high level
# Processing Record 48 of Set 1 | pevek
# Processing Record 49 of Set 1 | saldanha
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | daulatpur
# Processing Record 3 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 2 | mount gambier
# Processing Record 5 of Set 2 | sola
# Processing Record 6 of Set 2 | port macquarie
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | nantucket
# Processing Record 9 of Set 2 | seoul
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | evensk
# Processing Record 14 of Set 2 | san quintin
# Processing Record 15 of Set 2 | lasa
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | ornes
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | erenhot
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | surt
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | malanville
# Processing Record 25 of Set 2 | kaitangata
# Processing Record 26 of Set 2 | noumea
# Processing Record 27 of Set 2 | pankovka
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 2 | khatanga
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | bambous virieux
# Processing Record 34 of Set 2 | talaya
# Processing Record 35 of Set 2 | norrtalje
# Processing Record 36 of Set 2 | gazanjyk
# Processing Record 37 of Set 2 | airai
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | rio gallegos
# Processing Record 40 of Set 2 | afmadu
# City not found. Skipping...
# Processing Record 41 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 2 | severo-kurilsk
# Processing Record 43 of Set 2 | quatre cocos
# Processing Record 44 of Set 2 | chuy
# Processing Record 45 of Set 2 | camacha
# Processing Record 46 of Set 2 | pestretsy
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | ilanskiy
# Processing Record 49 of Set 2 | san cristobal
# Processing Record 50 of Set 2 | upernavik
# Processing Record 1 of Set 3 | srednekolymsk
# Processing Record 2 of Set 3 | poum
# Processing Record 3 of Set 3 | buala
# Processing Record 4 of Set 3 | iqaluit
# Processing Record 5 of Set 3 | labuhan
# Processing Record 6 of Set 3 | almaznyy
# Processing Record 7 of Set 3 | khani
# Processing Record 8 of Set 3 | kismayo
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | teneguiban
# City not found. Skipping...
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 3 | la roche-sur-yon
# Processing Record 14 of Set 3 | bilma
# Processing Record 15 of Set 3 | saint-francois
# Processing Record 16 of Set 3 | bethel
# Processing Record 17 of Set 3 | cockburn town
# Processing Record 18 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 3 | mar del plata
# Processing Record 20 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 21 of Set 3 | qostanay
# Processing Record 22 of Set 3 | fortuna
# Processing Record 23 of Set 3 | meulaboh
# Processing Record 24 of Set 3 | talnakh
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | esperance
# Processing Record 27 of Set 3 | vaini
# Processing Record 28 of Set 3 | canarana
# Processing Record 29 of Set 3 | tiznit
# Processing Record 30 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 3 | sao filipe
# Processing Record 32 of Set 3 | makakilo city
# Processing Record 33 of Set 3 | batemans bay
# Processing Record 34 of Set 3 | muros
# Processing Record 35 of Set 3 | mancio lima
# Processing Record 36 of Set 3 | camocim
# Processing Record 37 of Set 3 | bengkulu
# Processing Record 38 of Set 3 | ye
# City not found. Skipping...
# Processing Record 39 of Set 3 | waipawa
# Processing Record 40 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 3 | jonkoping
# Processing Record 42 of Set 3 | den helder
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | buraydah
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | nichinan
# Processing Record 47 of Set 3 | sakhipur
# Processing Record 48 of Set 3 | poddorye
# Processing Record 49 of Set 3 | puerto rico
# Processing Record 50 of Set 3 | vardo
# Processing Record 1 of Set 4 | katete
# Processing Record 2 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 4 | jimo
# Processing Record 4 of Set 4 | avarua
# Processing Record 5 of Set 4 | port alfred
# Processing Record 6 of Set 4 | mahebourg
# Processing Record 7 of Set 4 | aswan
# Processing Record 8 of Set 4 | tuatapere
# Processing Record 9 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 4 | morros
# Processing Record 11 of Set 4 | botro
# Processing Record 12 of Set 4 | lodja
# Processing Record 13 of Set 4 | coihaique
# Processing Record 14 of Set 4 | curillo
# Processing Record 15 of Set 4 | narsaq
# Processing Record 16 of Set 4 | anahuac
# Processing Record 17 of Set 4 | tautira
# Processing Record 18 of Set 4 | ahuimanu
# Processing Record 19 of Set 4 | fernandopolis
# Processing Record 20 of Set 4 | toora-khem
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | duzce
# Processing Record 23 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 24 of Set 4 | port lincoln
# Processing Record 25 of Set 4 | wladyslawowo
# Processing Record 26 of Set 4 | belaya gora
# Processing Record 27 of Set 4 | dunedin
# Processing Record 28 of Set 4 | malmesbury
# Processing Record 29 of Set 4 | kununurra
# Processing Record 30 of Set 4 | thinadhoo
# Processing Record 31 of Set 4 | sorong
# Processing Record 32 of Set 4 | acajutla
# Processing Record 33 of Set 4 | rawson
# Processing Record 34 of Set 4 | cusco
# Processing Record 35 of Set 4 | kavieng
# Processing Record 36 of Set 4 | tilichiki
# Processing Record 37 of Set 4 | ubauro
# Processing Record 38 of Set 4 | pangnirtung
# Processing Record 39 of Set 4 | kieta
# Processing Record 40 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 4 | rudnyy
# Processing Record 42 of Set 4 | berlevag
# Processing Record 43 of Set 4 | bethanien
# Processing Record 44 of Set 4 | coulihaut
# City not found. Skipping...
# Processing Record 45 of Set 4 | provideniya
# Processing Record 46 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 47 of Set 4 | erzincan
# Processing Record 48 of Set 4 | hilo
# Processing Record 49 of Set 4 | codrington
# Processing Record 50 of Set 4 | tallahassee
# Processing Record 1 of Set 5 | shimoda
# Processing Record 2 of Set 5 | hamilton
# Processing Record 3 of Set 5 | klaksvik
# Processing Record 4 of Set 5 | rio grande
# Processing Record 5 of Set 5 | hengyang
# Processing Record 6 of Set 5 | alice springs
# Processing Record 7 of Set 5 | kirakira
# Processing Record 8 of Set 5 | maiduguri
# Processing Record 9 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 5 | gusau
# Processing Record 12 of Set 5 | zaysan
# Processing Record 13 of Set 5 | pareora
# Processing Record 14 of Set 5 | roebourne
# Processing Record 15 of Set 5 | torbay
# Processing Record 16 of Set 5 | atasu
# Processing Record 17 of Set 5 | la ronge
# Processing Record 18 of Set 5 | reconquista
# Processing Record 19 of Set 5 | tarbes
# Processing Record 20 of Set 5 | valdivia
# Processing Record 21 of Set 5 | ravar
# Processing Record 22 of Set 5 | ambon
# Processing Record 23 of Set 5 | okha
# Processing Record 24 of Set 5 | clarksburg
# Processing Record 25 of Set 5 | nikolskoye
# Processing Record 26 of Set 5 | huron
# Processing Record 27 of Set 5 | dera din panah
# City not found. Skipping...
# Processing Record 28 of Set 5 | ruston
# Processing Record 29 of Set 5 | chokurdakh
# Processing Record 30 of Set 5 | kalmunai
# Processing Record 31 of Set 5 | los andes
# Processing Record 32 of Set 5 | castro
# Processing Record 33 of Set 5 | carutapera
# Processing Record 34 of Set 5 | mildura
# Processing Record 35 of Set 5 | lugovoy
# Processing Record 36 of Set 5 | clyde river
# Processing Record 37 of Set 5 | pemangkat
# Processing Record 38 of Set 5 | caravelas
# Processing Record 39 of Set 5 | east london
# Processing Record 40 of Set 5 | hokitika
# Processing Record 41 of Set 5 | hammerfest
# Processing Record 42 of Set 5 | saint anthony
# Processing Record 43 of Set 5 | daru
# Processing Record 44 of Set 5 | haines junction
# Processing Record 45 of Set 5 | balikpapan
# Processing Record 46 of Set 5 | husavik
# Processing Record 47 of Set 5 | antofagasta
# Processing Record 48 of Set 5 | smithers
# Processing Record 49 of Set 5 | yeppoon
# Processing Record 50 of Set 5 | taveta
# Processing Record 1 of Set 6 | vilcun
# Processing Record 2 of Set 6 | yarada
# Processing Record 3 of Set 6 | menongue
# Processing Record 4 of Set 6 | merauke
# Processing Record 5 of Set 6 | chivilcoy
# Processing Record 6 of Set 6 | la cruz
# Processing Record 7 of Set 6 | bud
# Processing Record 8 of Set 6 | sokoni
# Processing Record 9 of Set 6 | leshukonskoye
# Processing Record 10 of Set 6 | cherskiy
# Processing Record 11 of Set 6 | sindhnur
# Processing Record 12 of Set 6 | leningradskiy
# Processing Record 13 of Set 6 | souillac
# Processing Record 14 of Set 6 | vila
# Processing Record 15 of Set 6 | deputatskiy
# Processing Record 16 of Set 6 | wattegama
# Processing Record 17 of Set 6 | ribas do rio pardo
# Processing Record 18 of Set 6 | muisne
# Processing Record 19 of Set 6 | mitsamiouli
# Processing Record 20 of Set 6 | kodiak
# Processing Record 21 of Set 6 | vyartsilya
# Processing Record 22 of Set 6 | bandarbeyla
# Processing Record 23 of Set 6 | amga
# Processing Record 24 of Set 6 | chicama
# Processing Record 25 of Set 6 | sinnamary
# Processing Record 26 of Set 6 | roma
# Processing Record 27 of Set 6 | guerrero negro
# Processing Record 28 of Set 6 | copiapo
# Processing Record 29 of Set 6 | lebu
# Processing Record 30 of Set 6 | sept-iles
# Processing Record 31 of Set 6 | carnarvon
# Processing Record 32 of Set 6 | bathsheba
# Processing Record 33 of Set 6 | panama city
# Processing Record 34 of Set 6 | suntar
# Processing Record 35 of Set 6 | amapa
# Processing Record 36 of Set 6 | upington
# Processing Record 37 of Set 6 | fairbanks
# Processing Record 38 of Set 6 | constitucion
# Processing Record 39 of Set 6 | beyneu
# Processing Record 40 of Set 6 | hirara
# Processing Record 41 of Set 6 | najran
# Processing Record 42 of Set 6 | sibolga
# Processing Record 43 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 44 of Set 6 | conde
# Processing Record 45 of Set 6 | kisangani
# Processing Record 46 of Set 6 | babushkin
# Processing Record 47 of Set 6 | yibin
# Processing Record 48 of Set 6 | cirie
# Processing Record 49 of Set 6 | luanda
# Processing Record 50 of Set 6 | kasulu
# Processing Record 1 of Set 7 | sao joao da barra
# Processing Record 2 of Set 7 | angoche
# Processing Record 3 of Set 7 | geraldton
# Processing Record 4 of Set 7 | freeport
# Processing Record 5 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 7 | verkhnya syrovatka
# Processing Record 7 of Set 7 | kargil
# Processing Record 8 of Set 7 | vila franca do campo
# Processing Record 9 of Set 7 | comodoro rivadavia
# Processing Record 10 of Set 7 | svetlaya
# Processing Record 11 of Set 7 | iki-burul
# Processing Record 12 of Set 7 | barra
# Processing Record 13 of Set 7 | luwuk
# Processing Record 14 of Set 7 | kaoma
# Processing Record 15 of Set 7 | malakal
# Processing Record 16 of Set 7 | port-gentil
# Processing Record 17 of Set 7 | zatoka
# Processing Record 18 of Set 7 | samarai
# Processing Record 19 of Set 7 | tiksi
# Processing Record 20 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 22 of Set 7 | santo domingo
# Processing Record 23 of Set 7 | am timan
# Processing Record 24 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 7 | edirne
# Processing Record 26 of Set 7 | mazatlan
# Processing Record 27 of Set 7 | bismarck
# Processing Record 28 of Set 7 | joshimath
# Processing Record 29 of Set 7 | neuquen
# Processing Record 30 of Set 7 | marystown
# Processing Record 31 of Set 7 | jiaonan
# Processing Record 32 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 7 | mikhaylovka
# Processing Record 34 of Set 7 | methoni
# Processing Record 35 of Set 7 | lixourion
# Processing Record 36 of Set 7 | kermanshah
# Processing Record 37 of Set 7 | aykhal
# Processing Record 38 of Set 7 | nome
# Processing Record 39 of Set 7 | charleston
# Processing Record 40 of Set 7 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 41 of Set 7 | the pas
# Processing Record 42 of Set 7 | luderitz
# Processing Record 43 of Set 7 | honiara
# Processing Record 44 of Set 7 | pervomayskoye
# Processing Record 45 of Set 7 | golden
# Processing Record 46 of Set 7 | puerto quijarro
# Processing Record 47 of Set 7 | homer
# Processing Record 48 of Set 7 | takoradi
# Processing Record 49 of Set 7 | kapit
# Processing Record 50 of Set 7 | kishi
# Processing Record 1 of Set 8 | mount isa
# Processing Record 2 of Set 8 | gimli
# Processing Record 3 of Set 8 | santa catarina de tepehuanes
# Processing Record 4 of Set 8 | mocuba
# Processing Record 5 of Set 8 | dingle
# Processing Record 6 of Set 8 | komsomolskiy
# Processing Record 7 of Set 8 | bandar-e anzali
# Processing Record 8 of Set 8 | wloclawek
# Processing Record 9 of Set 8 | surovikino
# Processing Record 10 of Set 8 | grande prairie
# Processing Record 11 of Set 8 | lata
# Processing Record 12 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 13 of Set 8 | magdagachi
# Processing Record 14 of Set 8 | sitio novo do tocantins
# Processing Record 15 of Set 8 | coquimbo
# Processing Record 16 of Set 8 | havoysund
# Processing Record 17 of Set 8 | northam
# Processing Record 18 of Set 8 | palauig
# Processing Record 19 of Set 8 | nelson bay
# Processing Record 20 of Set 8 | krasnoobsk
# Processing Record 21 of Set 8 | faanui
# Processing Record 22 of Set 8 | stara tura
# Processing Record 23 of Set 8 | uray
# Processing Record 24 of Set 8 | alamosa
# Processing Record 25 of Set 8 | novopskov
# Processing Record 26 of Set 8 | islamkot
# Processing Record 27 of Set 8 | bridlington
# Processing Record 28 of Set 8 | qafqafa
# Processing Record 29 of Set 8 | ugoofaaru
# Processing Record 30 of Set 8 | iralaya
# Processing Record 31 of Set 8 | kozhva
# Processing Record 32 of Set 8 | yichang
# Processing Record 33 of Set 8 | tacna
# Processing Record 34 of Set 8 | lagoa
# Processing Record 35 of Set 8 | muromtsevo
# Processing Record 36 of Set 8 | solnechnyy
# Processing Record 37 of Set 8 | harper
# Processing Record 38 of Set 8 | hasaki
# Processing Record 39 of Set 8 | thunder bay
# Processing Record 40 of Set 8 | luocheng
# Processing Record 41 of Set 8 | guajara
# Processing Record 42 of Set 8 | robertsport
# Processing Record 43 of Set 8 | nanortalik
# Processing Record 44 of Set 8 | micheweni
# Processing Record 45 of Set 8 | katsuura
# Processing Record 46 of Set 8 | ovsyanka
# Processing Record 47 of Set 8 | cap malheureux
# Processing Record 48 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 8 | taoudenni
# Processing Record 50 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 9 | palmer
# Processing Record 2 of Set 9 | huai yot
# Processing Record 3 of Set 9 | iskateley
# Processing Record 4 of Set 9 | ponta delgada
# Processing Record 5 of Set 9 | sabang
# Processing Record 6 of Set 9 | loreto
# Processing Record 7 of Set 9 | manta
# Processing Record 8 of Set 9 | riyadh
# Processing Record 9 of Set 9 | pavino
# Processing Record 10 of Set 9 | san patricio
# Processing Record 11 of Set 9 | barahona
# Processing Record 12 of Set 9 | rundu
# Processing Record 13 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 14 of Set 9 | moron
# Processing Record 15 of Set 9 | buin
# Processing Record 16 of Set 9 | filadelfia
# Processing Record 17 of Set 9 | naze
# Processing Record 18 of Set 9 | freetown
# Processing Record 19 of Set 9 | llanes
# Processing Record 20 of Set 9 | tayshet
# Processing Record 21 of Set 9 | pringsewu
# Processing Record 22 of Set 9 | mali
# Processing Record 23 of Set 9 | kudahuvadhoo
# Processing Record 24 of Set 9 | oga
# Processing Record 25 of Set 9 | qasigiannguit
# Processing Record 26 of Set 9 | ventspils
# Processing Record 27 of Set 9 | vila velha
# Processing Record 28 of Set 9 | noyabrsk
# Processing Record 29 of Set 9 | ninghai
# Processing Record 30 of Set 9 | kloulklubed
# Processing Record 31 of Set 9 | nueva londres
# Processing Record 32 of Set 9 | grindavik
# Processing Record 33 of Set 9 | staryy nadym
# Processing Record 34 of Set 9 | lazaro cardenas
# Processing Record 35 of Set 9 | drabiv
# Processing Record 36 of Set 9 | broome
# Processing Record 37 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 9 | dubti
# Processing Record 39 of Set 9 | terney
# Processing Record 40 of Set 9 | kutum
# Processing Record 41 of Set 9 | tiarei
# Processing Record 42 of Set 9 | salalah
# Processing Record 43 of Set 9 | champerico
# Processing Record 44 of Set 9 | sur
# Processing Record 45 of Set 9 | etchoropo
# Processing Record 46 of Set 9 | buluang
# Processing Record 47 of Set 9 | devils lake
# Processing Record 48 of Set 9 | gravdal
# Processing Record 49 of Set 9 | necochea
# Processing Record 50 of Set 9 | mumford
# Processing Record 1 of Set 10 | lubango
# Processing Record 2 of Set 10 | griffith
# Processing Record 3 of Set 10 | amuntai
# Processing Record 4 of Set 10 | novyy urengoy
# Processing Record 5 of Set 10 | gao
# Processing Record 6 of Set 10 | huilong
# Processing Record 7 of Set 10 | cascais
# Processing Record 8 of Set 10 | santa cruz
# Processing Record 9 of Set 10 | richards bay
# Processing Record 10 of Set 10 | rocha
# Processing Record 11 of Set 10 | grand gaube
# Processing Record 12 of Set 10 | flinders
# Processing Record 13 of Set 10 | asfi
# Processing Record 14 of Set 10 | alta gracia
# Processing Record 15 of Set 10 | nouadhibou
# Processing Record 16 of Set 10 | balingasay
# Processing Record 17 of Set 10 | mitchell
# Processing Record 18 of Set 10 | peniche
# Processing Record 19 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 20 of Set 10 | tall kayf
# Processing Record 21 of Set 10 | ponta do sol
# Processing Record 22 of Set 10 | yulara
# Processing Record 23 of Set 10 | wagar
# Processing Record 24 of Set 10 | port augusta
# Processing Record 25 of Set 10 | kamenka
# Processing Record 26 of Set 10 | tateyama
# Processing Record 27 of Set 10 | umm kaddadah
# Processing Record 28 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 10 | shambu
# Processing Record 30 of Set 10 | upata
# Processing Record 31 of Set 10 | mehamn
# Processing Record 32 of Set 10 | codo
# Processing Record 33 of Set 10 | kabwe
# Processing Record 34 of Set 10 | cetate
# Processing Record 35 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 10 | tevaitoa
# Processing Record 37 of Set 10 | polyarnyy
# Processing Record 38 of Set 10 | kashan
# Processing Record 39 of Set 10 | puerto del rosario
# Processing Record 40 of Set 10 | koppang
# Processing Record 41 of Set 10 | ixtapa
# Processing Record 42 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 43 of Set 10 | temirtau
# Processing Record 44 of Set 10 | abu samrah
# Processing Record 45 of Set 10 | okandja
# City not found. Skipping...
# Processing Record 46 of Set 10 | susanville
# Processing Record 47 of Set 10 | junction city
# Processing Record 48 of Set 10 | pangody
# Processing Record 49 of Set 10 | vao
# Processing Record 50 of Set 10 | santiago del estero
# Processing Record 1 of Set 11 | cayenne
# Processing Record 2 of Set 11 | sukumo
# Processing Record 3 of Set 11 | saint-philippe
# Processing Record 4 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 5 of Set 11 | cortez
# Processing Record 6 of Set 11 | kourou
# Processing Record 7 of Set 11 | anadyr
# Processing Record 8 of Set 11 | miami
# Processing Record 9 of Set 11 | botshabelo
# Processing Record 10 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 11 of Set 11 | comarapa
# Processing Record 12 of Set 11 | krasni okny
# Processing Record 13 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 14 of Set 11 | ostersund
# Processing Record 15 of Set 11 | ust-tsilma
# Processing Record 16 of Set 11 | kupang
# Processing Record 17 of Set 11 | broken hill
# Processing Record 18 of Set 11 | tabou
# Processing Record 19 of Set 11 | yamada
# Processing Record 20 of Set 11 | new amsterdam
# Processing Record 21 of Set 11 | dedovichi
# Processing Record 22 of Set 11 | yarmouth
# Processing Record 23 of Set 11 | chilca
# Processing Record 24 of Set 11 | voinesti
# Processing Record 25 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 11 | sitka
# Processing Record 27 of Set 11 | bose
# Processing Record 28 of Set 11 | nuuk
# Processing Record 29 of Set 11 | znamenskoye
# Processing Record 30 of Set 11 | nampa
# Processing Record 31 of Set 11 | vanimo
# Processing Record 32 of Set 11 | bintulu
# Processing Record 33 of Set 11 | lompoc
# Processing Record 34 of Set 11 | kushima
# Processing Record 35 of Set 11 | cooma
# Processing Record 36 of Set 11 | hobyo
# Processing Record 37 of Set 11 | popondetta
# Processing Record 38 of Set 11 | catamarca
# Processing Record 39 of Set 11 | la fleche
# Processing Record 40 of Set 11 | knysna
# Processing Record 41 of Set 11 | chumikan
# Processing Record 42 of Set 11 | tura
# Processing Record 43 of Set 11 | zhezkazgan
# Processing Record 44 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 45 of Set 11 | taitung
# Processing Record 46 of Set 11 | gornyy
# Processing Record 47 of Set 11 | tingi
# Processing Record 48 of Set 11 | umm lajj
# Processing Record 49 of Set 11 | aklavik
# Processing Record 50 of Set 11 | posse
# Processing Record 1 of Set 12 | pacific grove
# Processing Record 2 of Set 12 | fuling
# Processing Record 3 of Set 12 | semporna
# Processing Record 4 of Set 12 | nybro
# Processing Record 5 of Set 12 | treinta y tres
# Processing Record 6 of Set 12 | egvekinot
# Processing Record 7 of Set 12 | puerto carreno
# Processing Record 8 of Set 12 | illela
# Processing Record 9 of Set 12 | kundiawa
# Processing Record 10 of Set 12 | jiaozuo
# Processing Record 11 of Set 12 | hoima
# Processing Record 12 of Set 12 | belem de sao francisco
# Processing Record 13 of Set 12 | orbetello
# Processing Record 14 of Set 12 | skjervoy
# Processing Record 15 of Set 12 | zhigansk
# Processing Record 16 of Set 12 | gairo
# Processing Record 17 of Set 12 | kidal
# Processing Record 18 of Set 12 | inirida
# Processing Record 19 of Set 12 | manyoni
# Processing Record 20 of Set 12 | saint paul
# Processing Record 21 of Set 12 | beloha
# Processing Record 22 of Set 12 | aljezur
# Processing Record 23 of Set 12 | ust-nera
# Processing Record 24 of Set 12 | male
# Processing Record 25 of Set 12 | mendi
# Processing Record 26 of Set 12 | trujillo
# Processing Record 27 of Set 12 | port hedland
# Processing Record 28 of Set 12 | smidovich
# Processing Record 29 of Set 12 | ashland
# Processing Record 30 of Set 12 | mucuri
# Processing Record 31 of Set 12 | mnogovershinnyy
# Processing Record 32 of Set 12 | obo
# Processing Record 33 of Set 12 | kiunga
# Processing Record 34 of Set 12 | pokhara
# Processing Record 35 of Set 12 | suihua
# Processing Record 36 of Set 12 | areosa
# Processing Record 37 of Set 12 | biscarrosse
# Processing Record 38 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 12 | mahon
# Processing Record 40 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 12 | douala
# Processing Record 42 of Set 12 | dera ghazi khan
# Processing Record 43 of Set 12 | saint-joseph
# Processing Record 44 of Set 12 | cozumel
# Processing Record 45 of Set 12 | warri
# Processing Record 46 of Set 12 | raton
# Processing Record 47 of Set 12 | nam som
# Processing Record 48 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 12 | khon buri
# Processing Record 50 of Set 12 | huarmey
# Processing Record 1 of Set 13 | kanaya
# Processing Record 2 of Set 13 | pisco
# Processing Record 3 of Set 13 | bantou
# Processing Record 4 of Set 13 | saskatoon
# Processing Record 5 of Set 13 | jalu
# Processing Record 6 of Set 13 | nalut
# Processing Record 7 of Set 13 | el pueblito
# Processing Record 8 of Set 13 | dejen
# Processing Record 9 of Set 13 | pravec
# City not found. Skipping...
# Processing Record 10 of Set 13 | turbat
# Processing Record 11 of Set 13 | puerto baquerizo moreno
# Processing Record 12 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 13 of Set 13 | imperia
# Processing Record 14 of Set 13 | maningrida
# Processing Record 15 of Set 13 | rovaniemi
# Processing Record 16 of Set 13 | milkovo
# Processing Record 17 of Set 13 | bandrele
# Processing Record 18 of Set 13 | oxelosund
# Processing Record 19 of Set 13 | mindelo
# Processing Record 20 of Set 13 | ormara
# Processing Record 21 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 22 of Set 13 | nuevitas
# Processing Record 23 of Set 13 | tessalit
# Processing Record 24 of Set 13 | pundaguitan
# Processing Record 25 of Set 13 | gat
# Processing Record 26 of Set 13 | nurota
# Processing Record 27 of Set 13 | bay city
# Processing Record 28 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 13 | bone
# Processing Record 30 of Set 13 | hargeysa
# Processing Record 31 of Set 13 | chipoka
# Processing Record 32 of Set 13 | bahia blanca
# Processing Record 33 of Set 13 | namibe
# Processing Record 34 of Set 13 | kijang
# Processing Record 35 of Set 13 | huazolotitlan
# City not found. Skipping...
# Processing Record 36 of Set 13 | malanje
# Processing Record 37 of Set 13 | victoria
# Processing Record 38 of Set 13 | caraquet
# Processing Record 39 of Set 13 | yamaranguila
# Processing Record 40 of Set 13 | guatire
# Processing Record 41 of Set 13 | borujerd
# Processing Record 42 of Set 13 | touros
# Processing Record 43 of Set 13 | rockingham
# Processing Record 44 of Set 13 | maine-soroa
# Processing Record 45 of Set 13 | mujiayingzi
# Processing Record 46 of Set 13 | kahului
# Processing Record 47 of Set 13 | tahe
# Processing Record 48 of Set 13 | yenagoa
# Processing Record 49 of Set 13 | rincon
# Processing Record 50 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 14 | channel-port aux basques
# Processing Record 2 of Set 14 | maxixe
# Processing Record 3 of Set 14 | bay roberts
# Processing Record 4 of Set 14 | yurga
# Processing Record 5 of Set 14 | nemuro
# Processing Record 6 of Set 14 | nyurba
# Processing Record 7 of Set 14 | awbari
# Processing Record 8 of Set 14 | jilib
# Processing Record 9 of Set 14 | valparaiso
# Processing Record 10 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 14 | vostok
# Processing Record 12 of Set 14 | oranjemund
# Processing Record 13 of Set 14 | pascoag
# Processing Record 14 of Set 14 | tecpatan
# Processing Record 15 of Set 14 | mezen
# Processing Record 16 of Set 14 | faya
# Processing Record 17 of Set 14 | kirove
# Processing Record 18 of Set 14 | alihe
# Processing Record 19 of Set 14 | dali
# Processing Record 20 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 14 | jiblah
# Processing Record 22 of Set 14 | gualaco
# Processing Record 23 of Set 14 | skibbereen
# Processing Record 24 of Set 14 | vanavara
# Processing Record 25 of Set 14 | maniitsoq
# Processing Record 26 of Set 14 | tuntum
# Processing Record 27 of Set 14 | itarema
# Processing Record 28 of Set 14 | college
# Processing Record 29 of Set 14 | kaspiysk
# Processing Record 30 of Set 14 | mvuma
# Processing Record 31 of Set 14 | woodward
# Processing Record 32 of Set 14 | monsenhor gil
# Processing Record 33 of Set 14 | venice
# Processing Record 34 of Set 14 | dongning
# Processing Record 35 of Set 14 | antalaha
# Processing Record 36 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 14 | tadine
# Processing Record 38 of Set 14 | safaga
# Processing Record 39 of Set 14 | roald
# Processing Record 40 of Set 14 | wilmington
# Processing Record 41 of Set 14 | sinjar
# Processing Record 42 of Set 14 | vilyuysk
# Processing Record 43 of Set 14 | lorengau
# Processing Record 44 of Set 14 | chimoio
# Processing Record 45 of Set 14 | bubaque
# Processing Record 46 of Set 14 | merritt island
# Processing Record 47 of Set 14 | kenora
# Processing Record 48 of Set 14 | beringovskiy
# Processing Record 49 of Set 14 | coahuayana
# Processing Record 50 of Set 14 | tommot
# Processing Record 1 of Set 15 | nedryhayliv
# Processing Record 2 of Set 15 | sampit
# Processing Record 3 of Set 15 | idenao
# Processing Record 4 of Set 15 | katherine
# Processing Record 5 of Set 15 | bajil
# Processing Record 6 of Set 15 | aginskoye
# Processing Record 7 of Set 15 | wanning
# Processing Record 8 of Set 15 | biarritz
# Processing Record 9 of Set 15 | fallon
# Processing Record 10 of Set 15 | shitkino
# Processing Record 11 of Set 15 | baruun-urt
# Processing Record 12 of Set 15 | el ejido
# Processing Record 13 of Set 15 | sarakhs
# Processing Record 14 of Set 15 | skovorodino
# Processing Record 15 of Set 15 | assare
# Processing Record 16 of Set 15 | punta gorda
# Processing Record 17 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 18 of Set 15 | novosokolniki
# Processing Record 19 of Set 15 | distraccion
# Processing Record 20 of Set 15 | sungaipenuh
# Processing Record 21 of Set 15 | ganzhou
# Processing Record 22 of Set 15 | akcaabat
# Processing Record 23 of Set 15 | chifeng
# Processing Record 24 of Set 15 | tatarbunary
# Processing Record 25 of Set 15 | voloshka
# Processing Record 26 of Set 15 | acapulco
# Processing Record 27 of Set 15 | havelock
# Processing Record 28 of Set 15 | ketchikan
# Processing Record 29 of Set 15 | latung
# Processing Record 30 of Set 15 | mazagao
# Processing Record 31 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 32 of Set 15 | coos bay
# Processing Record 33 of Set 15 | ziro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 675

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kruisfontein -34.0033   24.7314     60.89        60          21
# 1               Padang  -0.9492  100.3543     75.25        96         100
# 2             Goderich  43.7501  -81.7165     40.91        88         100
# 3            Alyangula -13.8483  136.4192     85.41        67           7
# 4  Ouro Preto Do Oeste -10.7481  -62.2158     79.70        67          99
# 5            Busselton -33.6500  115.3333     56.48        60          86
# 6               Albany  42.6001  -73.9662     52.36        74          64
# 7           Launceston -41.4500  147.1667     51.44        92         100
# 8         Saint George  37.1041 -113.5841     61.43        24           0
# 9         Punta Arenas -53.1500  -70.9167     53.11        54           3
#
#    Wind Speed Country Current Description
# 0       14.32      ZA          few clouds
# 1        4.00      ID          light rain
# 2       13.35      CA          light rain
# 3        7.67      AU           clear sky
# 4        2.64      BR     overcast clouds
# 5       11.18      AU     overcast clouds
# 6        1.99      US       broken clouds
# 7       12.66      AU       moderate rain
# 8        5.01      US           clear sky
# 9        8.84      CL           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df[new_column_order]
# Display sample data
# YOUR CODE HERE
city_data_df
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Kruisfontein      ZA -34.0033   24.7314     60.89        60
# 1                 Padang      ID  -0.9492  100.3543     75.25        96
# 2               Goderich      CA  43.7501  -81.7165     40.91        88
# 3              Alyangula      AU -13.8483  136.4192     85.41        67
# 4    Ouro Preto Do Oeste      BR -10.7481  -62.2158     79.70        67
# ..                   ...     ...      ...       ...       ...       ...
# 670            Ketchikan      US  55.3422 -131.6461     37.87        93
# 671               Latung      PH   5.5000  120.8833     82.67        75
# 672              Mazagao      BR  -0.1150  -51.2894     82.45        77
# 673             Coos Bay      US  43.3665 -124.2179     56.32        86
# 674                 Ziro      IN  27.6333   93.8333     40.21        92
#
#      Cloudiness  Wind Speed Current Description
# 0            21       14.32          few clouds
# 1           100        4.00          light rain
# 2           100       13.35          light rain
# 3             7        7.67           clear sky
# 4            99        2.64     overcast clouds
# ..          ...         ...                 ...
# 670         100       12.66          light rain
# 671          98        5.10     overcast clouds
# 672          31        6.20    scattered clouds
# 673           0       13.80           clear sky
# 674          22        2.86          few clouds
#
# [675 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file, index_label="City_ID")
